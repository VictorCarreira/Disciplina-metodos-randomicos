# %% [markdown]
# <p align="Right">
#   <img src="Images/logon.jpg" width="750"/>
# </p>

# %% [markdown]
# # O método da Busca Harmônica

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
import pylab as py
import math as ma
import random
from random import *
from IPython.display import Latex
#novos pacotes de imagem
import imageio
from skimage import data, io, filters
# %matplotlib inline

# %% [markdown]
# O algoritmo de busca harmônica foi originalmente desenvolvido por Geem and Loganathan(2001) e foi originalmente baseado nos processos de improvisação dos músicos jazzianos.

# %% [markdown]
# <p align="Right">
#   <img src="Images/original.png" width="750"/>
# </p>

# %% [markdown]
# Nesta lógica, cada músico corresponde a uma variável de decisão.

# %% [markdown]
# O instrumento musical corresponde a faixa  de valores onde o passo é uma faixa de valores em uma variável de decisão.

# %% [markdown]
# A harmonia musical corresponde a um vetor de soluções em uma determinada iteração.

# %% [markdown]
#  A estética da audiência corresponde a função objetivo que se quer minimizar.

# %% [markdown]
# Assim como um músico melhora a sua harmonia musical com o tempo o vetor de soluções é melhorado após cada iteração.

# %%
monograma = io.imread( "Images/The-HS-algorithm-concept.png")
py.rcParams['figure.figsize'] = (20.0, 10.0)
#plt.title("monograma (figura 1)")
fig = plt.imshow(monograma)
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# <p align="center">
#   <img src="Images/The-HS-algorithm-concept.png" width="950"/>
# </p>

# %% [markdown]
# ## Formulação do problema

# %% [markdown]
# O problema necessita de uma função objeto para ser otimizada variáveis dependentes e idependentes.

# %% [markdown]
# O algoritmo realiza uma busca no espaço de soluções com o objetivo de achar o vetor de soluções que otimiza a função objetivo.

# %% [markdown]
# Seja ***HM*** o vetor *Harmony Memory* onde cada posição na memória é ocupada por uma harmonia de tamanho ***n***. E o número de harmonias é ***m***.

# %% [markdown]
# \begin{equation*}
#   HM=
#   \left[ {\begin{array}{cc}
#    \{x_{1,1} & x_{1,2} & x_{1,3} & \cdots & x_{1,n} & | f(\vec{x}_{1,n})  \}\\
#    \{x_{2,1} & x_{2,2} & x_{2,3} & \cdots & x_{2,n} & | f(\vec{x}_{2,n})  \}\\
#    \{x_{3,1} & x_{3,2} & x_{3,3} & \cdots & x_{3,n} & | f(\vec{x}_{3,n})  \}\\
#    \vdots & \vdots & \vdots & \ddots & \vdots & \vdots\\
#    \{x_{4,1} & x_{4,2} & x_{4,3} & \cdots & x_{m,n} & | f(\vec{x}_{m,n})\}\\
#   \end{array} } \right]
# \end{equation*}

# %% [markdown]
# ## Pseudo-código

# %% [markdown]
# <p align="center">
#   <img src="Images/pseudocode.png" width="450"/>
# </p>
#
# * Fonte: Yang(2008)

# %% [markdown]
# \begin{enumerate}
# \item Inicie a memória harmônica, selecionando k vetores aleatórios $x_{1},...,x_{k}$
# \item repita
# \item    crie um novo vetor x'
# \item    para cada componente $x'_{i}$, faça
# \item        com probabilidade $p_{hmcr}$, faça $x'_{i} \longleftarrow x_{i}^{int(rand(0,1)*k+1)}$
# \item        com probabilidade $1- p_{hmcr}$, escolha um novo valor aleatório no intervalo
# \item para cada componente $x'_{i}$
# \end{enumerate}

# %% [markdown]
# ***Parâmetros***: HMS, HMCR, PAR, MI, FW
#
# ***Início***
#
# Função Objetivo $f(\vec{x}), \vec{x}=[x_{1},x_{2},...x_{n}]$
#
# Inicialização da Memória Harmônica $x^{i},i=1,2,...,m$
#
# Avalia cada harmonia na ***HM***: $f(x^{i})$

# %% [markdown]
# ciclo $\longleftarrow$ 1
#
# ***ENQUANTO*** ciclo $<$ MI ***FAÇA***
#
# ***PARA*** j$\longleftarrow$ 1 até n ***FAÇA***
#
# ***SE*** gerador_aleatorio() $\leq$ HMCR ***ENTÃO*** {taxa de consideração na memória}
#
# $x_{i,j}' \longleftarrow x_{i,j}$, com i $\in$ $[1,m]$ {escolhido aleatoriamente}
#
# ***SE*** gerador_aleatorio() $\leq$ PAR ***ENTÃO*** {taxa de ajuste fino}
#
# $x_{i,j}' \longleftarrow x_{i,j}'+u(-1,1) \times FW $
#
# ***FIM SE***

# %% [markdown]
# ***SENÃO*** {seleção aleatória}
#
# Gera $x_{i,j}'$ aleatoriamente
#
# ***FIM SE***
#
# ***FIM PARA***
#
# Avalia a nova Harmonia gerada: $f(x')$
#
# ***SE*** $f(x')$ é melhor que a pior Harmonia na HM ***ENTÃO***
#
# Atualiza Memória Harmônica
#
# ***FIM SE***
#
# ciclo $\longleftarrow$ ciclo + 1
#
# Verifica o critério de parada
#
# ***FIM ENQUANTO***
#
# Exibição dos resultados
#
# ***FIM***

# %% [markdown]
# ## Um exemplo de aplicação utilizando a Busca Harmônica:

# %% [markdown]
# Objetivo: calcular o valor da função constante $f(x)=-(x_{1}+x_{2})$, cuja solução analítica $-20$ é conhecida.

# %% [markdown]
# O programa guarda a melhor solução calculada na variável BestGen, e imprime na tela a solução a cada 1000  passos e armazena no arquivo ajuste.txt (213-214)

# %% [markdown]
# Para a análise da convergência é apresentada a solução analítica em conjunto com o resultado calculado pelo algoritmo em número máximo de iterações de $5000$, $10000$, $100000$ e $1000000$.

# %% [markdown]
# ***Parâmetros***:
#
# Variáveis| Significado
# ---------| :------------------------------------------------:
# HS       | Harmony memory
# HMS      | Harmony memory size (number of measured points)
# HMCR     | Harmony consideration rate
# PAR      | Pitch adjusting rate
# bw       | termination criterion
# MaxItr   | Maximal iteraction
# VAR      | Number of parameters

# %% [markdown]
#  ***Parâmetros Utilizados***:
#
# Variáveis| Valores
# ---------| :------------------------------------------------
# HS       | {x1,x2,f(x)}
# HMS      | 5
# HMCR     | Harmony consideration rate
# PAR      | 0.4(min) e 0.85(max)
# bw       | 0.01(min) e 4(max)
# MaxItr   | 5000,10000,100000,1000000
# VAR      | 2

# %% [markdown]
# ### Primeira rodada (5000 iterações):

# %%
fit5000=np.loadtxt('5000IT.txt')
print(fit5000)
# Out:
# [[-12.48806945   0.           0.        ]
#  [-19.99258698   9.99629349   9.99629349]
#  [-19.99258698   9.99629349   9.99629349]
#  [-19.99258698   9.99629349   9.99629349]
#  [-19.99258698   9.99629349   9.99629349]]

# %%
y=fit5000[:,0]
x1=fit5000[1]
x2=fit5000[2]
sol=-20.0

# %%
py.rcParams['figure.figsize'] = (20.0, 10.0)#Redimensiona a figura
plt.plot( sol,'bo',label="$Sol. analítica$") 
plt.plot( y, '-ro',label="Sol. calculada") 
legend = plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.title("Convergência (5.000 it.)", fontweight='bold', fontsize=25)
plt.tick_params(axis='both', labelsize=15)
plt.grid(True)
plt.xlabel("$Soluções$", fontsize=15)
plt.ylabel("$Y$", fontsize=15)
plt.savefig('FIT5000.png')  
plt.show()  
plt.close()

# %% [markdown]
# <p align="center">
#   <img src="Images/FIT5000.png" width="1050"/>
# </p>

# %%
#Erro:
err_y=np.absolute(np.mean(y)-sol)/np.absolute(sol)*100
print("erro%=",err_y)
# Out:
# erro%= 7.541582648541656

# %% [markdown]
# ### Segunda rodada (10.000 iterações)

# %%
fit10000=np.loadtxt('10000IT.txt')
print(fit10000)
# Out:
# [[-10.42709978   0.           0.        ]
#  [-19.78380173   9.89190087   9.89190087]
#  [-19.9396046    9.9698023    9.9698023 ]
#  [-19.95930716   9.97965358   9.97965358]
#  [-19.95930716   9.97965358   9.97965358]
#  [-19.95930716   9.97965358   9.97965358]
#  [-19.95930716   9.97965358   9.97965358]
#  [-19.95930716   9.97965358   9.97965358]
#  [-19.95930716   9.97965358   9.97965358]
#  [-19.95930716   9.97965358   9.97965358]]

# %%
y_10000=fit10000[:,0]
x1_10000=fit10000[1]
x2_10000=fit10000[2]
print(y_10000)
# Out:
# [-10.42709978 -19.78380173 -19.9396046  -19.95930716 -19.95930716
#  -19.95930716 -19.95930716 -19.95930716 -19.95930716 -19.95930716]

# %%
py.rcParams['figure.figsize'] = (20.0, 10.0)#Redimensiona a figura

plt.plot( sol,'bo',label="$Sol. analítica$") 
plt.plot( y_10000,'ro-',label="Sol. calculada") 


legend = plt.legend(loc='upper right', shadow=True, fontsize='x-large')

plt.title("Convergência (10.000 it.)", fontweight='bold', fontsize=25)
plt.tick_params(axis='both', labelsize=15)


plt.grid(True)
plt.xlabel("$Soluções$", fontsize=15)
plt.ylabel("$Y$", fontsize=15)
plt.savefig('FIT10000.png')  
plt.show()  
plt.close()

# %% [markdown]
# <p align="center">
#   <img src="Images/FIT10000.png" width="1050"/>
# </p>

# %%
#Erro:
err_10000=np.absolute(np.mean(y_10000)-sol)/np.absolute(sol)*100
print("erro%=",err_10000)
# Out:
# erro%= 5.067171897338003

# %% [markdown]
# ### Terceita rodada (100.000 iterações)

# %%
fit100000=np.loadtxt('100000IT.txt')
#print(fit100000)

# %%
y_100000=fit100000[:,0]
x1_100000=fit100000[1]
x2_100000=fit100000[2]
print(y_100000)
# Out:
# [-13.00415602 -19.79945894 -19.79945894 -19.79945894 -19.79945894
#  -19.91516021 -19.91516021 -19.91516021 -19.91516021 -19.91516021
#  -19.91516021 -19.91516021 -19.91516021 -19.98513575 -19.98513575
#  -19.98513575 -19.98513575 -19.98513575 -19.98513575 -19.98513575
#  -19.98513575 -19.98513575 -19.98513575 -19.98513575 -19.98513575
#  -19.98513575 -19.98513575 -19.98513575 -19.98513575 -19.98513575
#  -19.98513575 -19.98513575 -19.98513575 -19.98513575 -19.98513575
#  -19.98513575 -19.98513575 -19.98663852 -19.98663852 -19.98663852
#  -19.98663852 -19.98663852 -19.98663852 -19.98663852 -19.98663852
#  -19.98663852 -19.98663852 -19.98663852 -19.98663852 -19.98663852
#  -19.98663852 -19.98663852 -19.98663852 -19.98663852 -19.98663852
#  -19.98663852 -19.98663852 -19.98663852 -19.98663852 -19.98663852
#  -19.98663852 -19.98663852 -19.98663852 -19.98663852 -19.98663852
#  -19.98663852 -19.98663852 -19.98663852 -19.98663852 -19.98663852
# ...

# %%
py.rcParams['figure.figsize'] = (20.0, 10.0)#Redimensiona a figura

plt.plot( sol,'bo',label="$Sol. analítica$") 
plt.plot( y_100000, '-ro',label="Sol. calculada") 


legend = plt.legend(loc='upper right', shadow=True, fontsize='x-large')

plt.title("Convergência (100.000 it.)", fontweight='bold', fontsize=25)
plt.tick_params(axis='both', labelsize=15)


plt.grid(True)
plt.xlabel("$Soluções$", fontsize=15)
plt.ylabel("$Y$", fontsize=15)
plt.savefig('FIT100000.png')  
plt.show()  
plt.close()

# %% [markdown]
# <p align="center">
#   <img src="Images/FIT100000.png" width="1050"/>
# </p>

# %%
#Erro:
err_100000=np.absolute(np.mean(y_100000)-sol)/np.absolute(sol)*100
print("erro%=",err_100000)
# Out:
# erro%= 0.4837620849139235

# %% [markdown]
# ### Quarta rodada (1.000.000 iterações)

# %%
fit1000000=np.loadtxt('1000000IT.txt')
print(fit1000000)
# Out:
# [[-12.65278025   0.           0.        ]
#  [-19.60493448   9.80246724   9.80246724]
#  [-19.77318101   9.88658102   9.88659998]
#  ...
#  [-19.99873797   9.99936898   9.99936898]
#  [-19.99873797   9.99936898   9.99936898]
#  [-19.99873797   9.99936898   9.99936898]]

# %%
y_1000000=fit1000000[:,0]
x1_1000000=fit1000000[1]
x2_1000000=fit1000000[2]
#print(y_1000000)

# %%
py.rcParams['figure.figsize'] = (20.0, 10.0)#Redimensiona a figura
plt.plot( sol,'bo',label="$Sol. analítica$") 
plt.plot( y_1000000, '-ro',label="Sol. calculada") 
legend = plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.title("Convergência (1.000.000 it.)", fontweight='bold', fontsize=25)
plt.tick_params(axis='both', labelsize=15)
plt.grid(True)
plt.xlabel("$Soluções$", fontsize=15)
plt.ylabel("$Y$", fontsize=15)
plt.savefig('FIT1000000.png')  
plt.show()  
plt.close()

# %% [markdown]
# <p align="center">
#   <img src="Images/FIT1000000.png" width="1050"/>
# </p>

# %%
#Erro:
err_1000000=np.absolute(np.mean(y_1000000)-sol)/np.absolute(sol)*100
print("erro%=",err_1000000)
# Out:
# erro%= 0.06130144345148025

# %% [markdown]
# ## Conclusões e Discussão de resultado:

# %% [markdown]
# No início de cada teste é possível percebe-se que o valor inicial se afasta em muito da solução esperada.

# %% [markdown]
# Durante o avaçar das iterações nota-se uma rápida convergência para a solução esperada

# %% [markdown]
# O valor do erro diminui a medida que se aumentam o número de iterações

# %% [markdown]
# E o melhor teste observado foi o com valor máximo de iterações de $1000000$ que atigniu um erro percentual de $0.06130144345148025$

# %% [markdown]
# ## Próximas Etapas:

# %% [markdown]
# Resolver um problema de minimização

# %% [markdown]
# Adpatar o problema da esfera magnetizada.
